# %% [markdown]
# # Preliminaries

# %% [markdown]
# ## Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Libraries

# %%
# hide cell output
# %%capture

# imports
# !pip install geopandas
import pandas as pd
import geopandas as gpd
import fiona
import folium
from folium.plugins import TimestampedGeoJson
import ipywidgets as widgets
from IPython.display import display
from datetime import datetime
#import simplekml

# %% [markdown]
# ## Import & process overflight and facility data (raw, takes a long time)

# %%
# # overflight data
# this code is really slow. Is there any reason I have to use gpd.read_file instead of a pandas function?
sat = gpd.read_file("/content/drive/MyDrive/CORONA/declassified2.zip")
sat1 = gpd.read_file("/content/drive/MyDrive/CORONA/declassified1.zip")

# # facilities data
fac = pd.read_excel("/content/drive/MyDrive/CORONA/NL_geocoded_working.xlsx")

# %% [markdown]
# Transform the facilities dataframe into GeoDataFrame

# %%
# Clean up facilities df
fac = fac.drop(fac.columns[3], axis=1) # drop weird NaN column
fac = fac.dropna() # drop rows with missing coordinates, of which there are 11
fac = fac.reset_index(drop=True) # reset now missing indices

# Split Coordinates into two columns
fac['Coordinates'] = fac['Coordinates'].str.replace(',', '.') # deal with coordinate notation inconsistency
split_columns = fac['Coordinates'].str.split('.', expand=True) # split coords by periods
# split_columns[1] = split_columns[1].str[1:] # code was dropping the first digit after decimal point of Latitude. Why?
fac['Latitude'] = split_columns[0] + '.' + split_columns[1]
fac['Longitude'] = split_columns[2] + '.' + split_columns[3]

# Convert Lat and Long to spatial points - note that we are rounding to the nearest integer
# fac['Latitude'] = round(fac['Latitude'].astype(float))
# fac['Longitude'] = round(fac['Longitude'].astype(float))

# Create GeoDataFrame with facility locations
fac_geodf = gpd.GeoDataFrame(
    fac, geometry = gpd.points_from_xy(fac["Latitude"], fac["Longitude"]))

# Set the CRS to avoid CRS conflict with the overflight data
fac_geodf = fac_geodf.set_crs('epsg:4326')

# %% [markdown]
# Obtain capture data: Identify instances where a facility's coordinates were photographed in an overflight

# %%
# combine the sat dataframes
sat = pd.concat([sat, sat1], ignore_index=True)

# %%
# join the two GeoDataFrames
captures = gpd.tools.sjoin(fac_geodf, sat, predicate="within", how='left')

# the resulting GDF contains:
# a) each instance where an overflight photographed a polygon containing the coordinates of an enrichment facility AND
# b) a placeholder entry for each facility which was never photographed (no overlap with fac_geodf). Such entries have NaN or NaT values for all variables from fac_geodf (index_right through SW Corne_3)

# reset the indices and hang on to the facility IDs
captures = captures.reset_index(names = "fac_index")

# %% [markdown]
# Save data obtained to this point

# %%
# sat.to_csv("/content/drive/MyDrive/CORONA/sat.csv")
# captures.to_csv("/content/drive/MyDrive/CORONA/captures.csv")
# fac_geodf.to_csv("/content/drive/MyDrive/CORONA/fac_geodf.csv")

# %% [markdown]
# ## Import overflight, facility, & capture data (preprocessed)

# %%
# sat = pd.read_csv("/content/drive/MyDrive/CORONA/sat.csv")
# captures = pd.read_csv("/content/drive/MyDrive/CORONA/captures.csv")
# fac_geodf = gpd.read_file("/content/drive/MyDrive/CORONA/fac_geodf.csv",
                          # GEOM_POSSIBLE_NAMES="geometry",
                          # KEEP_GEOM_COLUMNS="NO")

# %% [markdown]
# ## Filter capture data

# %% [markdown]
# Do something about facilities with unknown start dates, denoted with a value of -99 in the dataset

# %%
# ---- OPTION 1 ----
# divide into two datasets - REMOVES facilities with unknown start date from analysis
# caps_unknownstart = captures[captures["start_date"] == -99] # capture occurences of facilities with unknown start dates
# captures = captures[(captures["start_date"] != -99) | (captures["start_date"].isna())] # capture occurences of facilities with known start dates AND facilities with no captures

# ---- OPTION 2 ----
# convert unknown start date (-99) to very early start date (1900) - ASSUMES facilities with unkown start date were built early
captures['start_date'] = captures['start_date'].replace(-99,1900)

# %%
captures
# Out:
#       fac_index original_country_name  original_ccode  \
# 0             0             Argentina             160
# 1             0             Argentina             160
# 2             0             Argentina             160
# 3             0             Argentina             160
# 4             0             Argentina             160
# ...         ...                   ...             ...
# 8270        156            Yugoslavia             345
# 8271        156            Yugoslavia             345
# 8272        156            Yugoslavia             345
# 8273        156            Yugoslavia             345
# 8274        156            Yugoslavia             345
#
#                      original_facility_name            Coordinates  \
# 0         Ezeiza – SF Reprocessing Facility  -34.854123.-58.522925
# 1         Ezeiza – SF Reprocessing Facility  -34.854123.-58.522925
# 2         Ezeiza – SF Reprocessing Facility  -34.854123.-58.522925
# 3         Ezeiza – SF Reprocessing Facility  -34.854123.-58.522925
# 4         Ezeiza – SF Reprocessing Facility  -34.854123.-58.522925
# ...                                     ...                    ...
# 8270  Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 8271  Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 8272  Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 8273  Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 8274  Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
#
#       start_date    Latitude   Longitude                     geometry  \
# 0           1968  -34.854123  -58.522925  POINT (-34.85412 -58.52293)
# 1           1968  -34.854123  -58.522925  POINT (-34.85412 -58.52293)
# 2           1968  -34.854123  -58.522925  POINT (-34.85412 -58.52293)
# 3           1968  -34.854123  -58.522925  POINT (-34.85412 -58.52293)
# 4           1968  -34.854123  -58.522925  POINT (-34.85412 -58.52293)
# ...          ...         ...         ...                          ...
# 8270        1949  46.0428588  14.4875933    POINT (46.04286 14.48759)
# 8271        1949  46.0428588  14.4875933    POINT (46.04286 14.48759)
# 8272        1949  46.0428588  14.4875933    POINT (46.04286 14.48759)
# 8273        1949  46.0428588  14.4875933    POINT (46.04286 14.48759)
# 8274        1949  46.0428588  14.4875933    POINT (46.04286 14.48759)
#
#       index_right  ... NW Corne_2 NW Corne_3 NE Corne_2  NE Corne_3  \
# 0         74884.0  ...    -39.772        NaN    -51.055     -30.475
# 1         74885.0  ...    -39.568        NaN    -52.552     -29.836
# 2         74886.0  ...     -39.28        NaN    -54.029     -29.082
# 3         74887.0  ...     -39.03        NaN    -55.506      -28.32
# 4         74888.0  ...      -38.7        NaN    -56.965     -27.439
# ...           ...  ...        ...        ...        ...         ...
# 8270     627759.0  ...     45.455        NaN     14.656      47.548
# 8271     772952.0  ...      43.95        NaN     14.616       46.35
# 8272     869728.0  ...     45.745        NaN     14.867       48.02
# 8273     869902.0  ...     45.739        NaN     14.958      47.951
# 8274     869903.0  ...     45.752        NaN     14.829      47.963
#
#       SE Corne_2 SE Corne_3 SW Corne_2 SW Corne_3  Direction  NW Cormer
# 0        -57.973    -26.221    -59.709    -37.186       012M     -52.51
# 1        -59.521    -25.194    -61.341    -36.799       012M    -54.057
# 2        -61.041    -23.977    -62.965    -36.276       012M    -55.598
# 3        -62.558      -22.7    -64.587    -35.775       012M    -57.137
# 4        -64.045     -21.21    -66.201    -35.131       012M     -58.67
# ...          ...        ...        ...        ...        ...        ...
# 8270      14.488     47.602     14.275     45.439       138D     14.449
# 8271      14.466       46.4       14.1      43.95       104D     14.266
# 8272      14.679     48.011     14.341     45.806       251D     14.512
# 8273      14.785     48.014     14.435     45.733       251D     14.621
# 8274      14.656     48.026     14.306     45.747       251D     14.492
#
# [8275 rows x 45 columns]

# %% [markdown]
# Filter out both capture events which happened before construction started on the facility and placeholders for facilities which were never captured

# %%
# convert to datetimes
captures['start_date'] = pd.to_datetime([f"{year}-01-01" for year in captures["start_date"]]).tz_localize(None) # assume construction started on the first day of the year
captures['Acquisitio'] = pd.to_datetime(captures['Acquisitio'])

# add unique indices (0 to n_captures) to each capture occurence, retaining facility indices (0 to n_facilities) as a separate column
# captures = captures.reset_index(names = "fac_index") # this is necessary when not loading captures from saved file
# captures.drop(columns=['Unnamed: 0']) # necessary when loading captures from saved file

# filter the dataset to remove cases:
# a) where the photo was taken before construction started, OR
# b) where the facility's coordinates were never captured at all
captures_filtered = captures[captures['start_date'] <= captures['Acquisitio']]
captures_filtered = captures_filtered.reset_index(drop = True) # reset indices

# %%
captures_filtered
# Out:
#       fac_index original_country_name  original_ccode  \
# 0             5               Belgium             211
# 1             5               Belgium             211
# 2             5               Belgium             211
# 3             5               Belgium             211
# 4             5               Belgium             211
# ...         ...                   ...             ...
# 5947        156            Yugoslavia             345
# 5948        156            Yugoslavia             345
# 5949        156            Yugoslavia             345
# 5950        156            Yugoslavia             345
# 5951        156            Yugoslavia             345
#
#                             original_facility_name            Coordinates  \
# 0     Mol, Purex Reprocessing Facility, Eurochemic     51.194551.5.119991
# 1     Mol, Purex Reprocessing Facility, Eurochemic     51.194551.5.119991
# 2     Mol, Purex Reprocessing Facility, Eurochemic     51.194551.5.119991
# 3     Mol, Purex Reprocessing Facility, Eurochemic     51.194551.5.119991
# 4     Mol, Purex Reprocessing Facility, Eurochemic     51.194551.5.119991
# ...                                            ...                    ...
# 5947         Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 5948         Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 5949         Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 5950         Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
# 5951         Jozef Stefan Institute near Ljubljana  46.0428588.14.4875933
#
#      start_date    Latitude   Longitude                   geometry  \
# 0    1960-01-01   51.194551    5.119991   POINT (51.19455 5.11999)
# 1    1960-01-01   51.194551    5.119991   POINT (51.19455 5.11999)
# 2    1960-01-01   51.194551    5.119991   POINT (51.19455 5.11999)
# 3    1960-01-01   51.194551    5.119991   POINT (51.19455 5.11999)
# 4    1960-01-01   51.194551    5.119991   POINT (51.19455 5.11999)
# ...         ...         ...         ...                        ...
# 5947 1949-01-01  46.0428588  14.4875933  POINT (46.04286 14.48759)
# 5948 1949-01-01  46.0428588  14.4875933  POINT (46.04286 14.48759)
# 5949 1949-01-01  46.0428588  14.4875933  POINT (46.04286 14.48759)
# 5950 1949-01-01  46.0428588  14.4875933  POINT (46.04286 14.48759)
# 5951 1949-01-01  46.0428588  14.4875933  POINT (46.04286 14.48759)
#
#       index_right  ... NW Corne_2 NW Corne_3 NE Corne_2  NE Corne_3  \
# 0         74515.0  ...     50.563        NaN      8.359       54.57
# 1         74516.0  ...     50.682        NaN        6.7      54.689
# 2        177465.0  ...     48.072        NaN      9.701      52.874
# 3        177466.0  ...     47.968        NaN      7.872       52.75
# 4        177467.0  ...     47.862        NaN      6.043      52.629
# ...           ...  ...        ...        ...        ...         ...
# 5947     627759.0  ...     45.455        NaN     14.656      47.548
# 5948     772952.0  ...      43.95        NaN     14.616       46.35
# 5949     869728.0  ...     45.745        NaN     14.867       48.02
# 5950     869902.0  ...     45.739        NaN     14.958      47.951
# 5951     869903.0  ...     45.752        NaN     14.829      47.963
#
#       SE Corne_2 SE Corne_3 SW Corne_2 SW Corne_3  Direction  NW Cormer
# 0          3.417     55.518      2.639     51.543       008M      7.574
# 1           1.74     55.643      0.958     51.657       008M      5.914
# 2          3.806     53.209      3.513     48.463       024M      9.405
# 3          1.973     53.093      1.679     48.352       024M      7.575
# 4          0.141      52.98     -0.155     48.238       024M      5.746
# ...          ...        ...        ...        ...        ...        ...
# 5947      14.488     47.602     14.275     45.439       138D     14.449
# 5948      14.466       46.4       14.1      43.95       104D     14.266
# 5949      14.679     48.011     14.341     45.806       251D     14.512
# 5950      14.785     48.014     14.435     45.733       251D     14.621
# 5951      14.656     48.026     14.306     45.747       251D     14.492
#
# [5952 rows x 45 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# How many of the facilities were ever photographed?

# %%
# total number of facilities
print("Total number of facilities:",len(fac['original_facility_name'].unique()))

# number of facilities with known start dates
print("Number of facilities with known start dates:",len(captures['original_facility_name'].unique()))

# number of facilities with known start dates which were photographed
print("Number of facilities with known start dates which were photographed:",len(captures_filtered['original_facility_name'].unique()))
# Out:
# Total number of facilities: 169

# %% [markdown]
# This means at least 157 - 85 = 72 facilities avoided detection by these CORONA flights. Worth mentioning that a fair number of these (20) were built after the end of the CORONA program.
#
# Let's make some tables & charts summarizing the coverage over time.

# %%
coverage = pd.DataFrame(columns=['year'])

for year in list(range(1959, 1981)):
  year_date = datetime(year, 1, 1)

  # extant facilities
  fac_exist = captures[captures['start_date'] <= year_date] # facilities which were built in or before year
  n_fac_exist = len(fac_exist['original_facility_name'].unique())

  # spotted facilities
  fac_spotted = captures_filtered[captures_filtered['Acquisitio'] <= year_date] # facilities which were spotted on or before Jan 1, year
  n_fac_spotted = len(fac_spotted['original_facility_name'].unique())

  coverage = pd.concat([coverage, pd.DataFrame({"year": [year],
                                                "number of extant facilities": n_fac_exist,
                                                "number of spotted facilities": n_fac_spotted,
                                                "coverage": n_fac_spotted/n_fac_exist})], ignore_index=True)

print(coverage)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e2ac70dd6d31> in <cell line: 3>()
#       5
#       6   # extant facilities
# ----> 7   fac_exist = captures[captures['start_date'] <= year_date] # facilities which were built in or before year
#       8   n_fac_exist = len(fac_exist['original_facility_name'].unique())
#       9
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __le__(self, other)
#      52     @unpack_zerodim_and_defer("__le__")
#      53     def __le__(self, other):
# ---> 54         return self._cmp_method(other, operator.le)
#      55
#      56     @unpack_zerodim_and_defer("__gt__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6241
#    6242         with np.errstate(all="ignore"):
# -> 6243             res_values = ops.comparison_op(lvalues, rvalues, op)
#    6244
#    6245         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     285
#     286     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     288
#     289     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      73         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74     else:
# ---> 75         result = libops.scalar_compare(x.ravel(), y, op)
#      76     return result.reshape(x.shape)
#      77
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<=' not supported between instances of 'str' and 'datetime.datetime'

# %%
coverage.plot.area(x='year',
                   y=["number of extant facilities", "number of spotted facilities"],
                   stacked = False,
                   color=['#7eb0d5','#fd7f6f'],
                   alpha=0.75)

# %%
captures.to_csv('captures.csv')
captures_filtered.to_csv('captures_filtered.csv')
coverage.to_csv('coverage.csv')

# %%
# pd.set_option("display.max_rows", None, "display.max_columns", None)
# pd.reset_option('^display.', silent=True)

# %% [markdown]
# # Prepare a map

# %%
#Provide the color column, not entirely necessary
# fac_geodf['fillColor'] = '#53c688'

# assume unknown start dates were built in 1900
fac_geodf['start_date'] = fac_geodf['start_date'].astype(int)
fac_geodf['start_date'] = fac_geodf['start_date'].replace(-99, 1900)

# captures_filtered['fillcolor'] = '#ac3977'

# get end date in milliseconds after Jan 1, 1960
end_date = captures_filtered["Acquisitio"].max().isoformat()
# end_date = (end_date - datetime(1970, 1, 1)).total_seconds()
# end_date = int(end_date * 1000)
# Out:
#     field_1 original_country_name original_ccode  \
# 0         0             Argentina            160
# 1         1             Argentina            160
# 2         2             Argentina            160
# 3         3             Australia            900
# 4         4             Australia            900
# ..      ...                   ...            ...
# 152     152        United Kingdom            200
# 153     153            Yugoslavia            345
# 154     154            Yugoslavia            345
# 155     155            Yugoslavia            345
# 156     156            Yugoslavia            345
#
#                                 original_facility_name  \
# 0                    Ezeiza – SF Reprocessing Facility
# 1                 Ezeiza II – SF Reprocessing Facility
# 2                     Pilcaniyeu Enrichment Facility I
# 3                                        Lucas Heights
# 4    Silex Laser Enrichment Facility at Lucas Heigh...
# ..                                                 ...
# 152                         MOX Demonstration Facility
# 153  Vinca Reprocessing Center near Belgrade (Boris...
# 154  Vinca Electromagnetic Isotope Separator (Vinca...
# 155                          Rudjer Boskovic Institute
# 156              Jozef Stefan Institute near Ljubljana
#
#                                 Coordinates  start_date Latitude Longitude  \
# 0                     -34.854123.-58.522925        1968    -35.0     -59.0
# 1                     -34.854123.-58.522925        1978    -35.0     -59.0
# 2                   -41.1226452.-70.7215709        1979    -41.0     -71.0
# 3                   -34.0506403.150.9872444        1965    -34.0     151.0
# 4              38.63805199999999.-90.221913        1982     39.0     -90.0
# ..                                      ...         ...      ...       ...
# 152                     54.425604.-3.500048        1900     54.0      -4.0
# 153  44.758497974697725. 20.598281709783674        1956     45.0      21.0
# 154  44.758497974697725. 20.598281709783675        1956     45.0      21.0
# 155                   45.8300113.15.9870591        1952     46.0      16.0
# 156                   46.0428588.14.4875933        1949     46.0      14.0
#
#                     geometry
# 0    POINT (-35.000 -59.000)
# 1    POINT (-35.000 -59.000)
# 2    POINT (-41.000 -71.000)
# 3    POINT (-34.000 151.000)
# 4     POINT (39.000 -90.000)
# ..                       ...
# 152    POINT (54.000 -4.000)
# 153    POINT (45.000 21.000)
# 154    POINT (45.000 21.000)
# 155    POINT (46.000 16.000)
# 156    POINT (46.000 14.000)
#
# [157 rows x 9 columns]

# %% [markdown]
# Map creation functions

# %%
fac_geodf_test = fac_geodf[fac_geodf['start_date'] >= 1970]
# Out:
#     field_1 original_country_name original_ccode  \
# 1         1             Argentina            160
# 2         2             Argentina            160
# 4         4             Australia            900
# 6         6                Brazil            140
# 7         7                Brazil            140
# 8         8                Brazil            140
# 10       10                Brazil            140
# 25       25                 Egypt            651
# 28       28                France            220
# 29       29                France            220
# 38       38                France            220
# 40       40                France            220
# 42       42                France            220
# 48       48               Germany            260
# 49       49               Germany            260
# 50       50               Germany            260
# 51       51                 India            750
# 53       53                 India            750
# 59       59                  Iraq            645
# 60       60                  Iraq            645
# 61       61                  Iraq            645
# 64       64                Israel            666
# 68       68                 Italy            325
# 69       69                 Italy            325
# 71       71                 Japan            740
# 72       72                 Japan            740
# 73       73                 Japan            740
# 74       74                 Japan            740
# 80       80           Netherlands            210
# 81       81           Netherlands            210
# 82       82           Netherlands            210
# 83       83           Netherlands            210
# 88       88              Pakistan            770
# 89       89              Pakistan            770
# 90       90              Pakistan            770
# 91       91              Pakistan            770
# 92       92              Pakistan            770
# 93       93              Pakistan            770
# 94       94               Romania            360
# 115     115                Russia            365
# 116     116                Russia            365
# 122     122                Russia            365
# 127     127          South Africa            560
# 128     128          South Africa            560
# 131     131          South Africa            560
# 138     138                Taiwan            713
# 139     139                Taiwan            713
# 140     140        United Kingdom            200
# 143     143        United Kingdom            200
# 151     151        United Kingdom            200
#
#                                 original_facility_name  \
# 1                 Ezeiza II – SF Reprocessing Facility
# 2                     Pilcaniyeu Enrichment Facility I
# 4    Silex Laser Enrichment Facility at Lucas Heigh...
# 6    Aerospace Technical Center (Institute of Advan...
# 7    BRN Enrichment (Aramar Isotopic Enrichment Lab...
# 8    INB Resende –Pilot Enrichment Facility, Rio De...
# 10   Pilot Enrichment Plant- Belo Horizonte (INB Re...
# 25   Hot Cell Facility at Inshas Nuclear Research C...
# 28                       Areva NC La Hague – UP2 – 800
# 29                             Areva NC La Hague – UP3
# 38                           Eurodif (Georges Besse I)
# 40                                                 PL4
# 42                                  Pierrelatte, Laser
# 48   Plutonium Test Extraction Facility (Reprocessi...
# 49                         Urenco Germany GmbH, Gronau
# 50                      Wackersdorf Reprocessing Plant
# 51                               BARC, Trombay (Pilot)
# 53   Center for Advanced Technology, Laser Enrichme...
# 59                                   Al Tuwaitha Laser
# 60                                Al Tuwaitha Hot Cell
# 61                       Al Tarmiya (north of Baghdad)
# 64      Negev Nuclear Research Center, Dimona Machon 9
# 68          Eurex SFRE (Oxide) at Saluggia in Vercelli
# 69   Eurex SFRE (PU Nitrate Line) Saluggia in Vercelli
# 71                 Asahi Uranium Enrichment Laboratory
# 72     JAEA Ningyo – Toge Enrichment Demo. Plant (DOP)
# 73   JAEA Tokai Reprocessing Plant (Japan Nuclear C...
# 74                   Ningyo – Toge Uranium Pilot Plant
# 80                                  Almelo SP1 (Dutch)
# 81   Almelo SP2 (German Plant adjacent to the Dutch...
# 82                            Almelo SP3 Demonstration
# 83                                          Almelo SP4
# 88                                            Chaklala
# 89                       Chashma Reprocessing Facility
# 90       Kahuta- KRL (A.Q. Khan Research Laboratories)
# 91   Experimental Reprocessing Plant at Pakistan In...
# 92                                New Labs at PINSTECH
# 93                                              Sihala
# 94                  Pitesti Nuclear Research Institute
# 115      RT–1, Combined Mayak in Ozersk/Chelyabinsk-65
# 116                                             RT – 2
# 122  Siberian Chemical Combine - Centrifuge (Severs...
# 127                                  Valindaba (Laser)
# 128                                Valindaba Y – Plant
# 131  Hot Cell Complex, Pelindaba Nuclear Research C...
# 138  Institute for Nuclear Energy Reaction (INER) R...
# 139  Institute for Nuclear Energy Reaction (INER) R...
# 140                                     Capenhurst A-3
# 143                                  Capenhurst (E-21)
# 151                                          NDA Thorp
#
#                                  Coordinates  start_date Latitude Longitude  \
# 1                      -34.854123.-58.522925        1978    -35.0     -59.0
# 2                    -41.1226452.-70.7215709        1979    -41.0     -71.0
# 4               38.63805199999999.-90.221913        1982     39.0     -90.0
# 6    -23.248269919363636. -45.85989846071746        1975    -23.0     -46.0
# 7                     -23.393281.-47.6047147        1976    -23.0     -48.0
# 8                    -22.4722561.-44.4649211        1982    -22.0     -44.0
# 10                    -19.919052.-43.9386685        1975    -20.0     -44.0
# 25                      30.387053.31.4440355        1980     30.0      31.0
# 28                     49.6639603.-1.8485699        1982     50.0      -2.0
# 29                     49.6639603.-1.8485699        1982     50.0      -2.0
# 38              44.33015095.4.72085710509542        1974     44.0       5.0
# 40                     50.3735195.-4.1197593        1984     50.0      -4.0
# 42       44.37775000000001.4.696981000000001        1984     44.0       5.0
# 48                      49.0068901.8.4036527        1977     49.0       8.0
# 49                      52.2121627.7.0755789        1982     52.0       7.0
# 50                       49.316069.12.167032        1985     49.0      12.0
# 51              19.0222081.72.92686259999999        1980     19.0      73.0
# 53                      44.633911.-85.767344        1984     45.0     -86.0
# 59      33.21350418284557. 44.51789711102107        1981     33.0      45.0
# 60      33.21350418284557. 44.51789711102107        1982     33.0      45.0
# 61                      33.315241.44.3660671        1982     33.0      44.0
# 64                           31.0013.35.1445        1972     31.0      35.0
# 68                      45.2353908.8.0105832        1976     45.0       8.0
# 69                      45.2353908.8.0105832        1981     45.0       8.0
# 71      35.55337768928075. 139.7488723630607        1982     36.0     140.0
# 72                    35.3137544.133.9305704        1985     35.0     134.0
# 73                    36.4729507.140.5661634        1971     36.0     141.0
# 74                    35.3137544.133.9305704        1978     35.0     134.0
# 80              52.3670267.6.668491899999999        1971     52.0       7.0
# 81              52.3670267.6.668491899999999        1971     52.0       7.0
# 82              52.3670267.6.668491899999999        1974     52.0       7.0
# 83              52.3670267.6.668491899999999        1979     52.0       7.0
# 88                     33.6030584.73.0936509        1974     34.0      73.0
# 89      32.38783404745864. 71.46836036157238        1974     32.0      71.0
# 90                     33.5896138.73.3885526        1974     34.0      73.0
# 91              33.65303430000001.73.2586063        1971     34.0      73.0
# 92     33.653150380723396. 73.25856338251063        1980     34.0      73.0
# 93              33.5440724.73.19691080000001        1976     34.0      73.0
# 94                     44.8564798.24.8691824        1981     45.0      25.0
# 115             55.7674306.60.69308710000001        1971     56.0      61.0
# 116                   42.5725316.-72.1553494        1976     43.0     -72.0
# 122      56.58911500000001.84.90131799999999        1973     57.0      85.0
# 127   -25.79947023459287. 27.943314911056277        1983    -26.0      28.0
# 128   -25.79947023459287. 27.943314911056277        1971    -26.0      28.0
# 131                     -25.943447.27.908954        1984    -26.0      28.0
# 138   24.854969689990586. 121.25335454819705        1970     25.0     121.0
# 139   24.854969689990586. 121.25335454819705        1975     25.0     121.0
# 140                    53.2612738.-2.9518011        1982     53.0      -3.0
# 143                    53.2612738.-2.9518011        1976     53.0      -3.0
# 151  54.415656058459966. -3.5017321880753305        1985     54.0      -4.0
#
#                         geometry
# 1    POINT (-35.00000 -59.00000)
# 2    POINT (-41.00000 -71.00000)
# 4     POINT (39.00000 -90.00000)
# 6    POINT (-23.00000 -46.00000)
# 7    POINT (-23.00000 -48.00000)
# 8    POINT (-22.00000 -44.00000)
# 10   POINT (-20.00000 -44.00000)
# 25     POINT (30.00000 31.00000)
# 28     POINT (50.00000 -2.00000)
# 29     POINT (50.00000 -2.00000)
# 38      POINT (44.00000 5.00000)
# 40     POINT (50.00000 -4.00000)
# 42      POINT (44.00000 5.00000)
# 48      POINT (49.00000 8.00000)
# 49      POINT (52.00000 7.00000)
# 50     POINT (49.00000 12.00000)
# 51     POINT (19.00000 73.00000)
# 53    POINT (45.00000 -86.00000)
# 59     POINT (33.00000 45.00000)
# 60     POINT (33.00000 45.00000)
# 61     POINT (33.00000 44.00000)
# 64     POINT (31.00000 35.00000)
# 68      POINT (45.00000 8.00000)
# 69      POINT (45.00000 8.00000)
# 71    POINT (36.00000 140.00000)
# 72    POINT (35.00000 134.00000)
# 73    POINT (36.00000 141.00000)
# 74    POINT (35.00000 134.00000)
# 80      POINT (52.00000 7.00000)
# 81      POINT (52.00000 7.00000)
# 82      POINT (52.00000 7.00000)
# 83      POINT (52.00000 7.00000)
# 88     POINT (34.00000 73.00000)
# 89     POINT (32.00000 71.00000)
# 90     POINT (34.00000 73.00000)
# 91     POINT (34.00000 73.00000)
# 92     POINT (34.00000 73.00000)
# 93     POINT (34.00000 73.00000)
# 94     POINT (45.00000 25.00000)
# 115    POINT (56.00000 61.00000)
# 116   POINT (43.00000 -72.00000)
# 122    POINT (57.00000 85.00000)
# 127   POINT (-26.00000 28.00000)
# 128   POINT (-26.00000 28.00000)
# 131   POINT (-26.00000 28.00000)
# 138   POINT (25.00000 121.00000)
# 139   POINT (25.00000 121.00000)
# 140    POINT (53.00000 -3.00000)
# 143    POINT (53.00000 -3.00000)
# 151    POINT (54.00000 -4.00000)

# %%
def create_geojson_features():
    features = []

    for _, row in fac_geodf_test.iterrows():
        x = int(row["start_date"])
        # Create a datetime object with the year, and set the month and day to 1
        dt = datetime(x, 1, 1)
        # Get the timestamp in seconds
        # timestamp_seconds = (dt - datetime(1970, 1, 1)).total_seconds()
        timestamp = dt.isoformat()
        # Convert timestamp to milliseconds
        # timestamp_milliseconds = int(timestamp_seconds * 1000)

        feature = {
            'type': 'Feature',
            'geometry': {
                'type':'Point',
                'coordinates':[float(row['Longitude']),float(row['Latitude'])]
            },
            'properties': {
                'times': [timestamp],  # Display until the end of the animation
                # 'times':[0],
                'style': {'color' : ''},
                'icon': 'circle',
                'iconstyle':{
                    'fillColor': 'blue',
                    'fillOpacity': 0.5,
                    'stroke': 'true',
                    'radius': 3
                },
                'name': 'Facilities'
            }
        }
        features.append(feature)

    # for _, row in captures_filtered.iterrows():
    #     y = row["Acquisitio"]
    #     # Get the timestamp in seconds
    #     # timestamp_seconds = (y - datetime(1970, 1, 1)).total_seconds()
    #     timestamp = y.isoformat()
    #     # Convert timestamp to milliseconds
    #     # timestamp_milliseconds = int(timestamp_seconds * 1000)

    #     feature = {
    #         'type': 'Feature',
    #         'geometry': {
    #             'type':'Point',
    #             'coordinates':[float(row['Longitude']),float(row['Latitude'])]
    #             # 'coordinates':[float(row['Latitude']),float(row['Longitude'])]
    #         },
    #         'properties': {
    #             # 'times': [timestamp_milliseconds, timestamp_milliseconds + (30 * 24 * 60 * 60 * 1000)],  # Display for 30 days
    #             # 'times': [timestamp], # display until the end of the animation
    #             'times':[0],
    #             'style': {'color' : ''},
    #             'icon': 'circle',
    #             'iconstyle':{
    #                 'fillColor': '#FF0000',
    #                 'fillOpacity': 0.8,
    #                 'stroke': 'true',
    #                 'radius': 4
    #             },
    #             'name': 'Overflights'
    #         }
    #     }
        # features.append(feature)
    return features

# %%
fac_geojson = create_geojson_features()

# Create the folium map
m = folium.Map()

#Add the slider
# Add TimestampedGeoJson layer to the map
# TimestampedGeoJson({
#     'type': 'FeatureCollection',
#     'features': fac_geojson
# }, period='P1M', duration='P1M', auto_play=False).add_to(m)

fac_geojson = sorted(fac_geojson, key=lambda x: x['properties']['times'][0])

TimestampedGeoJson(fac_geojson,transition_time=200,period='P1M').add_to(m)

# Add legend to the map
folium.LayerControl().add_to(m)

m
# m.save('map_test.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5873351f124fa41e8a69c58da7a8ab5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5873351f124fa41e8a69c58da7a8ab5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5873351f124fa41e8a69c58da7a8ab5b = L.map(
#                 &quot;map_5873351f124fa41e8a69c58da7a8ab5b&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db79ed3825b96b99cf7cae694119a62f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5873351f124fa41e8a69c58da7a8ab5b);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD HH:mm:ss&quot;);
#                 }
#             });
#             map_5873351f124fa41e8a69c58da7a8ab5b.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1M&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {&quot;autoPlay&quot;: true, &quot;loopButton&quot;: false, &quot;maxSpeed&quot;: 10, &quot;minSpeed&quot;: 0.1, &quot;playerOptions&quot;: {&quot;loop&quot;: true, &quot;startOver&quot;: true, &quot;transitionTime&quot;: 200}, &quot;position&quot;: &quot;bottomleft&quot;, &quot;speedSlider&quot;: true, &quot;timeSliderDragUpdate&quot;: false}
#             );
#             map_5873351f124fa41e8a69c58da7a8ab5b.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson([{&#x27;type&#x27;: &#x27;Feature&#x27;, &#x27;geometry&#x27;: {&#x27;type&#x27;: &#x27;Point&#x27;, &#x27;coordinates&#x27;: [121.0, 25.0]}, &#x27;properties&#x27;: {&#x27;times&#x27;: [&#x27;1970-01-01T00:00:00&#x27;], &#x27;style&#x27;: {&#x27;color&#x27;: &#x27;&#x27;}, &#x27;icon&#x27;: &#x27;circle&#x27;, &#x27;iconstyle&#x27;: {&#x27;fillColor&#x27;: &#x27;blue&#x27;, &#x27;fillOpacity&#x27;: 0.5, &#x27;stroke&#x27;: &#x27;true&#x27;, &#x27;radius&#x27;: 3}, &#x27;name&#x27;: &#x27;Facilities&#x27;}}, {&#x27;type&#x27;: &#x27;Feature&#x27;, &#x27;geometry&#x27;: {&#x27;type&#x27;: &#x27;Point&#x27;, &#x27;coordinates&#x27;: [141.0, 36.0]}, &#x27;properties&#x27;: {&#x27;times&#x27;: [&#x27;1971-01-01T00:00:00&#x27;], &#x27;style&#x27;: {&#x27;color&#x27;: &#x27;&#x27;}, &#x27;icon&#x27;: &#x27;circle&#x27;, &#x27;iconstyle&#x27;: {&#x27;fillColor&#x27;: &#x27;blue&#x27;, &#x27;fillOpacity&#x27;: 0.5, &#x27;stroke&#x27;: &#x27;true&#x27;, &#x27;radius&#x27;: 3}, &#x27;name&#x27;: &#x27;Facilities&#x27;}}, {&#x27;type&#x27;: &#x27;Feature&#x27;, &#x27;geometry&#x27;: {&#x27;type&#x27;: &#x27;Point&#x27;, &#x27;coordinates&#x27;: [7.0, 52.0]}, &#x27;properties&#x27;: {&#x27;times&#x27;: [&#x27;1971-01-01T00:00:00&#x27;], &#x27;style&#x27;: {&#x27;color&#x27;: &#x27;&#x27;}, &#x27;icon&#x27;: &#x27;circle&#x27;, &#x27;iconstyle&#x27;: {&#x27;fillColor&#x27;: &#x27;blue&#x27;, &#x27;fillOpacity&#x27;: 0.5, &#x27;stroke&#x27;: &#x27;true&#x27;, &#x27;radius&#x27;: 3}, &#x27;name&#x27;: &#x27;Facilities&#x27;}}, {&#x27;type&#x27;: &#x27;Feature&#x27;, &#x27;geometry&#x27;: {&#x27;type&#x27;: &#x27;Point&#x27;, &#x27;coordinates&#x27;: [7.0, 52.0]}, &#x27;properties&#x27;: {&#x27;times&#x27;: [&#x27;1971-01-01T00:00:00&#x27;], &#x27;style&#x27;: {&#x27;color&#x27;: &#x27;&#x27;}, &#x27;icon&#x27;: &#x27;circle&#x27;, &#x27;iconstyle&#x27;: {&#x27;fillColor&#x27;: &#x27;blue&#x27;, &#x27;fillOpacity&#x27;: 0.5, &#x27;stroke&#x27;: &#x27;true&#x27;, &#x27;radius&#x27;: 3}, &#x27;name&#x27;: &#x27;Facilities&#x27;}}, {&#x27;type&#x27;: &#x27;Feature&#x27;, &#

# %%
len(fac_geojson)
# Out:
# 50

# %%
datetime.fromisoformat(fac_geojson[0]['properties']['times'][0])
# and datetime(x['properties']['times'][0]) < datetime(1973,1,1)
filtered = filter(lambda x: datetime.fromisoformat(x['properties']['times'][0]) > datetime(1965,1,1), fac_geojson)
filtered = list(filtered)

pd.DataFrame.from_records(filtered)
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.0, 49.0]},
#   'properties': {'times': ['1966-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [8.0, 49.0]},
#   'properties': {'times': ['1967-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [51.0, 36.0]},
#   'properties': {'times': ['1967-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-59.0, -35.0]},
#   'properties': {'times': ['1968-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [105.0, 29.0]},
#   'properties': {'times': ['1968-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [6.0, 45.0]},
#   'properties': {'times': ['1968-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.0, 44.0]},
#   'properties': {'times': ['1968-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [141.0, 36.0]},
#   'properties': {'times': ['1968-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [106.0, 32.0]},
#   'properties': {'times': ['1969-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 19.0]},
#   'properties': {'times': ['1969-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [121.0, 25.0]},
#   'properties': {'times': ['1970-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [141.0, 36.0]},
#   'properties': {'times': ['1971-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.0, 52.0]},
#   'properties': {'times': ['1971-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.0, 52.0]},
#   'properties': {'times': ['1971-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 34.0]},
#   'properties': {'times': ['1971-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [61.0, 56.0]},
#   'properties': {'times': ['1971-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.0, -26.0]},
#   'properties': {'times': ['1971-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [35.0, 31.0]},
#   'properties': {'times': ['1972-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [85.0, 57.0]},
#   'properties': {'times': ['1973-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.0, 44.0]},
#   'properties': {'times': ['1974-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.0, 52.0]},
#   'properties': {'times': ['1974-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 34.0]},
#   'properties': {'times': ['1974-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [71.0, 32.0]},
#   'properties': {'times': ['1974-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 34.0]},
#   'properties': {'times': ['1974-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-46.0, -23.0]},
#   'properties': {'times': ['1975-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-44.0, -20.0]},
#   'properties': {'times': ['1975-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [121.0, 25.0]},
#   'properties': {'times': ['1975-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-48.0, -23.0]},
#   'properties': {'times': ['1976-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [8.0, 45.0]},
#   'properties': {'times': ['1976-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 34.0]},
#   'properties': {'times': ['1976-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.0, 43.0]},
#   'properties': {'times': ['1976-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.0, 53.0]},
#   'properties': {'times': ['1976-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [8.0, 49.0]},
#   'properties': {'times': ['1977-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-59.0, -35.0]},
#   'properties': {'times': ['1978-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [134.0, 35.0]},
#   'properties': {'times': ['1978-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-71.0, -41.0]},
#   'properties': {'times': ['1979-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.0, 52.0]},
#   'properties': {'times': ['1979-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [31.0, 30.0]},
#   'properties': {'times': ['1980-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 19.0]},
#   'properties': {'times': ['1980-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [73.0, 34.0]},
#   'properties': {'times': ['1980-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [45.0, 33.0]},
#   'properties': {'times': ['1981-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [8.0, 45.0]},
#   'properties': {'times': ['1981-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [25.0, 45.0]},
#   'properties': {'times': ['1981-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-90.0, 39.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-44.0, -22.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.0, 50.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.0, 50.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [7.0, 52.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [45.0, 33.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [44.0, 33.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [140.0, 36.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.0, 53.0]},
#   'properties': {'times': ['1982-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.0, -26.0]},
#   'properties': {'times': ['1983-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.0, 50.0]},
#   'properties': {'times': ['1984-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.0, 44.0]},
#   'properties': {'times': ['1984-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-86.0, 45.0]},
#   'properties': {'times': ['1984-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [28.0, -26.0]},
#   'properties': {'times': ['1984-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [12.0, 49.0]},
#   'properties': {'times': ['1985-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [134.0, 35.0]},
#   'properties': {'times': ['1985-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.0, 54.0]},
#   'properties': {'times': ['1985-01-01T00:00:00'],
#    'style': {'color': ''},
#    'icon': 'circle',
#    'iconstyle': {'fillColor': 'blue',
#     'fillOpacity': 0.5,
#     'stroke': 'true',
#     'radius': 3},
#    'name': 'Facilities'}}]

# %% [markdown]
# # Scratch

# %%
y = min(captures_filtered["Acquisitio"])

min(fac_geodf["start_date"])

(y - datetime(1970, 1, 1)).total_seconds()
# Out:
# 1900

# %%
timestamp_seconds = (y - datetime(1960, 1, 1)).total_seconds()
# Convert timestamp to milliseconds
timestamp_milliseconds = int(timestamp_seconds * 1000)

252460800000
252460800000

252460800000 (1968)
568080000000 (1978)
599616000000 (1979)

# n = number of milliseconds after 1960
n = 599616000000
(n/1000)/(60*60*24*365)

y = fac_geodf['start_date'][0]
dt.isoformat() = datetime(y, 1, 1)
(dt - datetime(1960, 1, 1)).total_seconds()
end_date
# Out:
# '1980-10-02T00:00:00'

# %% [markdown]
# Run the map

# %%
fac_geojson = create_geojson_features()
fac_geojson[0]

# Create the folium map
m = folium.Map(
    # location=[56.096555, -3.64746],
    # location=[0,0],
    # tiles="cartodbpositron",
    # zoom_start=2,
    # crs = 'EPSG4326'
)

#Add the slider
# Add TimestampedGeoJson layer to the map
TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': fac_geojson
}, period='P1M', duration='P1M', auto_play=False).add_to(m)

# Add legend to the map
folium.LayerControl().add_to(m)

#save
# m.save('C:/Users/hasko/OneDrive/Plocha/ETH Year 1 Materials/CSS - Nuclear/Map Project/map.html')

m
# m.save('map_test.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3188324648a4> in <cell line: 1>()
# ----> 1 fac_geojson = create_geojson_features()
#       2 fac_geojson[0]
#       3
#       4 # Create the folium map
#       5 m = folium.Map(
#
# NameError: name 'create_geojson_features' is not defined

# %%
m = folium.Map(
    location=[56.096555, -3.64746],
    tiles="cartodbpositron",
    zoom_start=2,
)

toy_feat = [{'type': 'Feature',
  'geometry': {'type': 'Point', 'coordinates': [-35.0, -59.0]},
  'properties': {'times': [0,0],
   'style': {'color': ''},
   'icon': 'circle',
   'iconstyle': {'fillColor': 'blue',
    'fillOpacity': 0.8,
    'stroke': 'true',
    'radius': 5},
   'name': 'Facilities'}}]

TimestampedGeoJson({
    'type': 'FeatureCollection',
    'features': toy_feat
}, period='P1M', duration='P1M', auto_play=False).add_to(m)

# Add legend to the map
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_395eec6bc33a86e8d078a186fee2dff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_395eec6bc33a86e8d078a186fee2dff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_395eec6bc33a86e8d078a186fee2dff7 = L.map(
#                 &quot;map_395eec6bc33a86e8d078a186fee2dff7&quot;,
#                 {
#                     center: [56.096555, -3.64746],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bac37367d101b41fea56a8f51e80638 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_395eec6bc33a86e8d078a186fee2dff7);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD HH:mm:ss&quot;);
#                 }
#             });
#             map_395eec6bc33a86e8d078a186fee2dff7.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1M&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {&quot;autoPlay&quot;: false, &quot;loopButton&quot;: false, &quot;maxSpeed&quot;: 10, &quot;minSpeed&quot;: 0.1, &quot;playerOptions&quot;: {&quot;loop&quot;: true, &quot;startOver&quot;: true, &quot;transitionTime&quot;: 200}, &quot;position&quot;: &quot;bottomleft&quot;, &quot;speedSlider&quot;: true, &quot;timeSliderDragUpdate&quot;: false}
#             );
#             map_395eec6bc33a86e8d078a186fee2dff7.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-35.0, -59.0]}, &quot;properties&quot;: {&quot;times&quot;: [0, 0], &quot;style&quot;: {&quot;color&quot;: &quot;&quot;}, &quot;icon&quot;: &quot;circle&quot;, &quot;iconstyle&quot;: {&quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.8, &quot;stroke&quot;: &quot;true&quot;, &quot;radius&quot;: 5}, &quot;name&quot;: &quot;Facilities&quot;}}]}, {
#                     pointToLayer: function (feature, latLng) {
#                         if (feature.properties.icon == &#x27;marker&#x27;) {
#                             if(feature.properties.iconstyle){
#                                 return new L.Marker(latLng, {
#                                     icon: L.icon(feature.properties.iconstyle)});
#                             }
#                             //else
#                             return new L.Marker(latLng);
#                         }
#                         if (feature.properties.icon == &#x27;circle&#x27;) {
#                             if (feature.properties.iconstyle) {
#                                 return new L.circleMarker(latLng, feature.properties.iconstyle)
#                                 };
#                             //else
#                             return new L.circleMarker(latLng);
#                         }
#                         //else
#
#                         return new L.Marker(latLng);
#                     },
#                     style: function (feature) {
#                         return feature.properties.style;
#                     },
#                     onEachFeature: function(feature, layer) {
#                         if (feature.properties.popup) {
#                         layer.bindPopup(feature.properties.popup);
#                         }
